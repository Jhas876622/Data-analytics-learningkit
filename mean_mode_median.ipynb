# %%
import pandas as pd
import numpy as np
import seaborn as sns
import statistics

# %%
data = [1,1,1,2,3,4,4,4,4,5,6,7,7,7,8]

# %%
1+1+1+2+3+4+4+4+4+5+6+7+7+7+8
# Out:
# 64

# %%
64/15
# Out:
# 4.266666666666667

# %%
statistics.mean(data)
# Out:
# 4.266666666666667

# %%
df = sns.load_dataset("mpg")

# %%
df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
statistics.mean(df["mpg"])
# Out:
# 23.514572864321607

# %%
 data = [1,1,1,2,3,4,4,4,4,5,6,7,7,7,8,50]

# %%
statistics.mean(data)
# Out:
# 4.266666666666667

# %%
statistics.median(data)
# Out:
# 4.0

# %%
statistics.mode(data)
# Out:
# 4

# %%
df.mode()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  13.0        4.0          97.0       150.0    1985          14.5
# 1   NaN        NaN           NaN         NaN    2130           NaN
#
#    model_year origin        name
# 0        73.0    usa  ford pinto
# 1         NaN    NaN         NaN

# %%
len(df[df["weight"]==1985])
# Out:
# 4

# %%
len(df[df["weight"]==2130])
# Out:
# 4

# %% [markdown]
# # MEASURE OD DISPERSION

# %%
data1 = [45,42,42,41,40]
data2 = [54,48,42,33,33]

# %%
statistics.mean(data1)
# Out:
# 42

# %% [markdown]
# statistics.mean(data2)

# %% [markdown]
# ## RANGE
# For ungrouped data, the range is the difference between the maximum and minimum values in a set of data.

# %%
max(data1)-min(data1)
# Out:
# 5

# %%
max(data2)-min(data1)
# Out:
# 14

# %% [markdown]
# ## VARIANCE

# %% [markdown]
# The variance is a measure of how far individual(numeric)values in a dataset are from the mean or a average value.

# %%
statistics.variance(data1)
# Out:
# 3.5

# %%
statistics.variance(data2)
# Out:
# 85.5

# %% [markdown]
# ## STANDARD DEVIATION
# It is a square root of variance. Low values of standard deviation tell us that individual values are closer to the mean. High values, on the other hand, tell us that individual observations are far away from the mean of the data.

# %%
statistics.pstdev(data1)
# Out:
# 1.6733200530681511

# %%
statistics.pstdev(data2)
# Out:
# 8.270429251254132

# %%
df = sns.load_dataset("mpg")

# %%
df.head(2)
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320

# %%
df["mpg"].max()-df["mpg"].min()
# Out:
# 37.6

# %%
df["weight"].max()-df["weight"].min()
# Out:
# 3527

# %%
statistics.variance(df["mpg"])
# Out:
# 61.0896107742744

# %%
statistics.pstdev(df["mpg"])
# Out:
# 7.806159061274432

# %%
statistics.mean(df["weight"])
# Out:
# 2970.424623115578

# %%
statistics.pstdev(df["weight"])
# Out:
# 845.7772335198175

# %%
df["weight"].max()
# Out:
# 5140

# %%
df["weight"].min()
# Out:
# 1613

# %% [markdown]
# ## QUARTILES
# Three points which divide the total data into four equal parts whern it has been orderly arranged are known as Quartiles.

# %%
age = [20,25,40,50,55,60,62]

# %%
statistics.median(age)
# Out:
# 50

# %% [markdown]
# Q2 = 50

# %% [markdown]
# Q1 = 32.5

# %% [markdown]
# Q3 = 115/2 = 57.5

# %%
df.describe()
# Out:
#               mpg   cylinders  displacement  horsepower       weight  \
# count  398.000000  398.000000    398.000000  392.000000   398.000000
# mean    23.514573    5.454774    193.425879  104.469388  2970.424623
# std      7.815984    1.701004    104.269838   38.491160   846.841774
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%     17.500000    4.000000    104.250000   75.000000  2223.750000
# 50%     23.000000    4.000000    148.500000   93.500000  2803.500000
# 75%     29.000000    8.000000    262.000000  126.000000  3608.000000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        acceleration  model_year
# count    398.000000  398.000000
# mean      15.568090   76.010050
# std        2.757689    3.697627
# min        8.000000   70.000000
# 25%       13.825000   73.000000
# 50%       15.500000   76.000000
# 75%       17.175000   79.000000
# max       24.800000   82.000000

# %% [markdown]
# ## COEFFICIENT OF VARIATION
# The coefficient of variation is obtained by dividing the standard deviation by the mean and expressed in percentage. Symbolically,
# coefficient of variation(C.V) = SD/Mean*100

# %%
statistics.mean([18,12,15])
# Out:
# 15
